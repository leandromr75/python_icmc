# %% [markdown]
# <center>
#
# # <span style="color:blue"> Evento DATA Day
# </center>

# %%
from IPython.display import Image
Image("divulgacao.jpg", width=500)

# %% [markdown]
# ---
# <br>
# <br>
# <br>
#
# O [DATA](https://www.facebook.com/dataICMC/) fará a primeira edição do **Data Day**: um evento com o objetivo de fazer a comunidade São-Carlense de Data Science conhecer o grupo Data e integrar alunos de graduação, pós graduação e profissionais que atuam nessa área.
#
# Cronograma do evento:
#
# - 13h00 - Abertura
#
# - 13h20 - Palestra: Predição categorias de produtos - Alcançando segundo lugar em um desafio de Ciências de Dados
#
# - 14h20 - Apresentação patrocinador
#
# - 14h35 - Amostra de projetos de Deep Learning
#
# - 15h15 - Mesa redonda: "Desafios atuais de Ciência de Dados" e "Como será o futuro da área?"
#
# - 16h15 - Coffee de encerramento
#
#
# Apoio:
# - CCEx, ICMC
# - Big Data
#
#
# As inscrições são limitadas!
#
# Inscrições: https://docs.google.com/forms/d/e/1FAIpQLScKftFjBFr70XhIiMvyHKk93rBB1o8PQ549GeD6ivH4FxnutQ/viewform
#
#
#
# <br>
# <br>
# <br>
#
# Sigua nossa página para ficar atualizado de futúros eventos: https://www.facebook.com/dataICMC/
